# %%
pip install numpy

# %%
Nama= "Widya Wati"
Npm= "18111280"

print (Nama);
print (Npm);
# Out:
# Widya Wati
# 18111280

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/project303/dataset/master/data-province-2015.cvs"
df = pd.read_csv(url, sep= '\t')

df.head()
# Out:
#          province  rainfall  rainy_day  ...  unemployment  time_zone    island
# 0            Aceh    1575.0        146  ...          9.93          1  Sumatera
# 1  Sumatera Utara     975.9        105  ...          6.71          1  Sumatera
# 2  Sumatera Barat    3548.0        185  ...          6.89          1  Sumatera
# 3            Riau    2048.3        140  ...          7.83          1  Sumatera
# 4           Jambi    1694.9        135  ...          4.34          1  Sumatera
#
# [5 rows x 10 columns]

# %% [markdown]
# menampilkan data row dengan 10 data (judul)

# %%
df.tail()
# Out:
#           province  rainfall  rainy_day  ...  unemployment  time_zone    island
# 29  Sulawesi Barat    1167.9         93  ...          3.35          2  Sulawesi
# 30          Maluku    1987.2        167  ...          9.93          3    Maluku
# 31    Maluku Utara     913.4        127  ...          6.05          3    Maluku
# 32     Papua Barat    2844.6        218  ...          8.08          3     Papua
# 33           Papua    1265.9        168  ...          3.99          3     Papua
#
# [5 rows x 10 columns]

# %% [markdown]
# menampilkan data paling terakhir

# %%
df.sample(10)
# Out:
#                province  rainfall  ...  time_zone         island
# 15               Banten    1310.1  ...          1           Jawa
# 0                  Aceh    1575.0  ...          1       Sumatera
# 24       Sulawesi Utara    1807.0  ...          2       Sulawesi
# 23     Kalimantan Utara    2311.5  ...          2     Kalimantan
# 14           Jawa Timur    2024.7  ...          1           Jawa
# 31         Maluku Utara     913.4  ...          3         Maluku
# 1        Sumatera Utara     975.9  ...          1       Sumatera
# 28            Gorontalo     870.6  ...          2       Sulawesi
# 12          Jawa Tengah    1620.7  ...          1           Jawa
# 18  Nusa Tenggara Timur    1406.0  ...          2  Nusa Tenggara
#
# [10 rows x 10 columns]

# %% [markdown]
# menampilkan data kolom sebanyak 10 baris

# %%
df
# Out:
#                      province  rainfall  ...  time_zone           island
# 0                        Aceh    1575.0  ...          1         Sumatera
# 1              Sumatera Utara     975.9  ...          1         Sumatera
# 2              Sumatera Barat    3548.0  ...          1         Sumatera
# 3                        Riau    2048.3  ...          1         Sumatera
# 4                       Jambi    1694.9  ...          1         Sumatera
# 5            Sumatera Selatan    1947.2  ...          1         Sumatera
# 6                    Bengkulu    2668.9  ...          1         Sumatera
# 7                     Lampung    1628.1  ...          1         Sumatera
# 8   Kepulauan Bangka Belitung    1534.7  ...          1  Bangka Belitung
# 9              Kepulauan Riau    2250.9  ...          1             Riau
# 10                DKI Jakarta    2169.5  ...          1             Jawa
# 11                 Jawa Barat    2199.3  ...          1             Jawa
# ...

# %% [markdown]
# menampilkan ke seluruhan data

# %%
df.count()
# Out:
# province                34
# rainfall                34
# rainy_day               34
# expenses_food_urban     34
# expenses_other_urban    34
# expenses_food_rural     34
# expense_other_rural     34
# unemployment            34
# time_zone               34
# island                  34
# dtype: int64

# %% [markdown]
# menampilkna jumlah data keseluruhan

# %%
df.shape
# Out:
# (34, 10)

# %% [markdown]
# 34 baris 10 kolom

# %%
df.dtypes
# Out:
# province                 object
# rainfall                float64
# rainy_day                 int64
# expenses_food_urban       int64
# expenses_other_urban      int64
# expenses_food_rural      object
# expense_other_rural      object
# unemployment            float64
# time_zone                 int64
# island                   object
# dtype: object

# %% [markdown]
# jenis tipe data nya

# %%
df[['province', 'unemployment', 'expenses_food_urban']].head()
# Out:
#          province  unemployment  expenses_food_urban
# 0            Aceh          9.93               466355
# 1  Sumatera Utara          6.71               416073
# 2  Sumatera Barat          6.89               509609
# 3            Riau          7.83               530836
# 4           Jambi          4.34               464204

# %% [markdown]
# menampilkan data kolom provinci umemployment dan expenses_food_urban

# %%
df[(df.island == "Sumatera")].head()
# Out:
#          province  rainfall  rainy_day  ...  unemployment  time_zone    island
# 0            Aceh    1575.0        146  ...          9.93          1  Sumatera
# 1  Sumatera Utara     975.9        105  ...          6.71          1  Sumatera
# 2  Sumatera Barat    3548.0        185  ...          6.89          1  Sumatera
# 3            Riau    2048.3        140  ...          7.83          1  Sumatera
# 4           Jambi    1694.9        135  ...          4.34          1  Sumatera
#
# [5 rows x 10 columns]

# %% [markdown]
# tampil data dengan valu data island adalah sumatera

# %%
df.sort_values('rainfall').head()
# Out:
#            province  rainfall  rainy_day  ...  unemployment  time_zone    island
# 25  Sulawesi Tengah     460.9         68  ...          4.10          2  Sulawesi
# 28        Gorontalo     870.6         76  ...          4.65          2  Sulawesi
# 31     Maluku Utara     913.4        127  ...          6.05          3    Maluku
# 1    Sumatera Utara     975.9        105  ...          6.71          1  Sumatera
# 16             Bali    1133.8        124  ...          1.99          2      Bali
#
# [5 rows x 10 columns]

# %% [markdown]
# tampilkan data dengan value rendah berdasarkan baris rainfall

# %%
df.sort_values('rainfall', ascending=False).head()
# Out:
#              province  rainfall  rainy_day  ...  unemployment  time_zone      island
# 2      Sumatera Barat    3548.0        185  ...          6.89          1    Sumatera
# 26   Sulawesi Selatan    3382.0        155  ...          5.95          2    Sulawesi
# 32        Papua Barat    2844.6        218  ...          8.08          3       Papua
# 19   Kalimantan Barat    2757.7        215  ...          5.15          1  Kalimantan
# 20  Kalimantan Tengah    2748.4        155  ...          4.54          1  Kalimantan
#
# [5 rows x 10 columns]

# %% [markdown]
# tampilkan data dengan value tanpa ascending berdasarkan baris rainfall
